# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Set sensible defaults
sns.set()
sns.set_style("ticks")

# %%
df_papers = pd.read_csv("papers_data.csv")
df_papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      2000 non-null   object
#  1   summary    2000 non-null   object
#  2   url        2000 non-null   object
#  3   published  2000 non-null   object
#  4   authors    2000 non-null   object
# dtypes: object(5)
# memory usage: 78.2+ KB

# %%
df_papers['description'] = df_papers.apply(lambda row: f"PAPER: {row['title']} [{row['published']}] | {row['summary']}", axis=1)

# %%
df_repos = pd.read_csv("repo_data.csv")
df_repos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     100 non-null    object
#  1   description              94 non-null     object
#  2   url                      100 non-null    object
#  3   createdAt                100 non-null    object
#  4   updatedAt                100 non-null    object
#  5   diskUsage                100 non-null    int64
#  6   forkCount                100 non-null    int64
#  7   isArchived               100 non-null    bool
#  8   isFork                   100 non-null    bool
#  9   isMirror                 100 non-null    bool
#  10  isPrivate                100 non-null    bool
#  11  stargazers.totalCount    100 non-null    int64
#  12  languages.nodes          100 non-null    object
#  13  licenseInfo.name         73 non-null     object
#  14  owner.login              100 non-null    object
#  15  primaryLanguage.name     87 non-null     object
#  16  pullRequests.totalCount  100 non-null    int64
#  17  issues.totalCount        100 non-null    int64
#  18  watchers.totalCount      100 non-null    int64
#  19  licenseInfo              0 non-null      float64
#  20  primaryLanguage          0 non-null      float64
# dtypes: bool(4), float64(2), int64(6), object(9)
# memory usage: 13.8+ KB

# %%
df_repos.rename(columns={
    'name': 'title',
    'description': 'summary',
}, inplace=True)

# %%
df_repos['description'] = df_repos.apply(lambda row: f"REPO: {row['title']} [{row['createdAt']}, stars: {row['stargazers.totalCount']}] | {row['summary']}", axis=1)

# %%
df_merged = pd.concat([df_papers, df_repos], ignore_index=True)
df_merged.sample(20)[['title', 'url', 'description']]
# Out:
#                                                   title  \
# 1859  Bulk and film synthesis pathways to ternary ma...
# 1086  Shear Viscosity expression for Graphene system...
# 1206  Global existence of 2D electron MHD near a ste...
# 622   Design and processing as ultrathin films of a ...
# 839   Strain, Young's modulus, and structural transi...
# 213                Interaction-mitigated Landau damping
# 469     Better sensing with variable-range interactions
# 995   Efficient Reduction of Casimir Forces by Self-...
# 807   Electronic structure of the Ge/Si(105) hetero-...
# 2046                                         geddit-app
# 1321  Generation and Measurement of Ultrashort Free ...
# 378   Exploring the Impact of Ions on Oxygen K-Edge ...
# 26    Colossal magnetoresistance in Ti lightly-doped...
# 874     Axion-Like Particles at future $e^- p$ collider
# 1068  Same-Sign Taus Signatures of Maximally Flavor-...
# 1227  Electronic Polarization Effects in Core-Level ...
# 817   Phase imaging in scanning transmission electro...
# 599   Doping driven metal-insulator transition in di...
# 65    The Emerging Weak Antilocalization Effect in S...
# 618   Kibble-Zurek Mechanism for Nonequilibrium Gene...
#
#                                             url  \
# 1859          http://arxiv.org/abs/2306.02233v1
# 1086          http://arxiv.org/abs/2306.14747v2
# 1206          http://arxiv.org/abs/2306.13036v1
# 622           http://arxiv.org/abs/2307.04591v1
# 839           http://arxiv.org/abs/2307.01022v1
# 213           http://arxiv.org/abs/2307.11169v1
# 469           http://arxiv.org/abs/2307.06901v1
# 995           http://arxiv.org/abs/2306.16209v1
# 807           http://arxiv.org/abs/2307.01604v1
# 2046  https://github.com/kaangiray26/geddit-app
# 1321          http://arxiv.org/abs/2306.11410v1
# 378           http://arxiv.org/abs/2307.08215v1
# 26            http://arxiv.org/abs/2307.13843v1
# 874           http://arxiv.org/abs/2307.00394v1
# 1068          http://arxiv.org/abs/2306.14957v1
# 1227          http://arxiv.org/abs/2306.12825v1
# 817           http://arxiv.org/abs/2307.01392v1
# 599           http://arxiv.org/abs/2307.04883v1
# 65            http://arxiv.org/abs/2307.13385v1
# 618           http://arxiv.org/abs/2307.05267v1
#
#                                             description
# 1859  PAPER: Bulk and film synthesis pathways to ter...
# 1086  PAPER: Shear Viscosity expression for Graphene...
# 1206  PAPER: Global existence of 2D electron MHD nea...
# 622   PAPER: Design and processing as ultrathin film...
# 839   PAPER: Strain, Young's modulus, and structural...
# 213   PAPER: Interaction-mitigated Landau damping [2...
# 469   PAPER: Better sensing with variable-range inte...
# 995   PAPER: Efficient Reduction of Casimir Forces b...
# 807   PAPER: Electronic structure of the Ge/Si(105) ...
# 2046  REPO: geddit-app [2023-07-01T18:03:01Z, stars:...
# 1321  PAPER: Generation and Measurement of Ultrashor...
# 378   PAPER: Exploring the Impact of Ions on Oxygen ...
# 26    PAPER: Colossal magnetoresistance in Ti lightl...
# 874   PAPER: Axion-Like Particles at future $e^- p$ ...
# 1068  PAPER: Same-Sign Taus Signatures of Maximally ...
# 1227  PAPER: Electronic Polarization Effects in Core...
# 817   PAPER: Phase imaging in scanning transmission ...
# 599   PAPER: Doping driven metal-insulator transitio...
# 65    PAPER: The Emerging Weak Antilocalization Effe...
# 618   PAPER: Kibble-Zurek Mechanism for Nonequilibri...

# %%
df_merged.shape
# Out:
# (2100, 24)

# %%
df_merged.to_csv("merged_data_full.csv", index=False)
df_merged[['title', 'url', 'description']].to_csv("merged_data.csv", index=False)
