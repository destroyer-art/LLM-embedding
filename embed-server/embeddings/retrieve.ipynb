# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Set sensible defaults
sns.set()
sns.set_style("ticks")
sns.set_context('talk')

# %%
import requests
import json
from datetime import datetime, timedelta
import os
from dotenv import load_dotenv 
load_dotenv()

# Setup access_token, you can generate one from Github Developer Settings
access_token=os.getenv("GITHUB_ACCESS_TOKEN")

headers = {'Authorization':"Bearer "+access_token, 'Content-Type':'application/json'}

# calculate the date 1 week ago and 1 month ago
date_one_week_ago = datetime.now() - timedelta(weeks=1)
date_one_week_ago_iso = date_one_week_ago.isoformat()

date_one_month_ago = datetime.now() - timedelta(weeks=4)
date_one_month_ago_iso = date_one_month_ago.isoformat()

# Create the GraphQL query
# Note: GitHub's GraphQL API only allows fetching the first 100 records in one request
# Create the GraphQL query
query = """
{{
  repos: search(query: "stars:>200 created:>{date_one_month_ago} archived:false sort:stars-desc", type: REPOSITORY, first: 100) {{
    repositoryCount
    edges {{
      node {{
        ... on Repository {{
          name
          description
          url
          stargazers {{
            totalCount
          }}
          createdAt
          updatedAt
          diskUsage
          forkCount
          isArchived
          isFork
          isMirror
          isPrivate
          languages(first:3) {{
            nodes {{
              name
            }}
          }}
          licenseInfo {{
            name
          }}
          owner {{
            login
          }}
          primaryLanguage {{
            name
          }}
          pullRequests {{
            totalCount
          }}
          issues {{
            totalCount
          }}
          watchers {{
            totalCount
          }}
        }}
      }}
    }}
  }}
}}
""".format(date_one_week_ago=date_one_week_ago_iso, date_one_month_ago=date_one_month_ago_iso)

# Send the POST request to the GitHub GraphQL API
response = requests.post('https://api.github.com/graphql', headers=headers, json={'query': query})

# Ensure the request was successful
if response.status_code == 200:
    data = json.loads(response.content.decode('utf-8'))
    print(json.dumps(data, indent=4))
else:
    print('Error', response.status_code, response.text)
# Out:
# {
#     "data": {
#         "repos": {
#             "repositoryCount": 132,
#             "edges": [
#                 {
#                     "node": {
#                         "name": "llama2.c",
#                         "description": "Inference Llama 2 in one file of pure C",
#                         "url": "https://github.com/karpathy/llama2.c",
#                         "stargazers": {
#                             "totalCount": 8452
#                         },
#                         "createdAt": "2023-07-23T05:15:06Z",
#                         "updatedAt": "2023-07-27T10:05:45Z",
#                         "diskUsage": 614,
#                         "forkCount": 610,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "C"
#                                 },
#                                 {
#                                     "name": "Makefile"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "karpathy"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 80
#                         },
#                         "issues": {
#                             "totalCount": 55
#                         },
#                         "watchers": {
#                             "totalCount": 96
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "python-mastery",
#                         "description": "Advanced Python Mastery (course by @dabeaz)",
#                         "url": "https://github.com/dabeaz-course/python-mastery",
#                         "stargazers": {
#                             "totalCount": 6868
#                         },
#                         "createdAt": "2023-07-17T01:11:15Z",
#                         "updatedAt": "2023-07-27T09:45:43Z",
#                         "diskUsage": 5354,
#                         "forkCount": 853,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Creative Commons Attribution Share Alike 4.0 International"
#                         },
#                         "owner": {
#                             "login": "dabeaz-course"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 16
#                         },
#                         "issues": {
#                             "totalCount": 14
#                         },
#                         "watchers": {
#                             "totalCount": 43
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "MetaGPT",
#                         "description": "\ud83c\udf1f The Multi-Agent Framework: Given one line Requirement, return PRD, Design, Tasks, Repo",
#                         "url": "https://github.com/geekan/MetaGPT",
#                         "stargazers": {
#                             "totalCount": 6437
#                         },
#                         "createdAt": "2023-06-30T09:04:55Z",
#                         "updatedAt": "2023-07-27T10:01:17Z",
#                         "diskUsage": 3337,
#                         "forkCount": 823,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Dockerfile"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "geekan"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 36
#                         },
#                         "issues": {
#                             "totalCount": 46
#                         },
#                         "watchers": {
#                             "totalCount": 244
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "gpt-prompt-engineer",
#                         "description": null,
#                         "url": "https://github.com/mshumer/gpt-prompt-engineer",
#                         "stargazers": {
#                             "totalCount": 4128
#                         },
#                         "createdAt": "2023-07-04T03:47:09Z",
#                         "updatedAt": "2023-07-27T05:03:45Z",
#                         "diskUsage": 36,
#                         "forkCount": 238,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "mshumer"
#                         },
#                         "primaryLanguage": {
#                             "name": "Jupyter Notebook"
#                         },
#                         "pullRequests": {
#                             "totalCount": 6
#                         },
#                         "issues": {
#                             "totalCount": 14
#                         },
#                         "watchers": {
#                             "totalCount": 37
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "InternLM",
#                         "description": "InternLM has open-sourced a 7 billion parameter base model, a chat model tailored for practical scenarios and the training system.",
#                         "url": "https://github.com/InternLM/InternLM",
#                         "stargazers": {
#                             "totalCount": 2278
#                         },
#                         "createdAt": "2023-07-06T04:52:06Z",
#                         "updatedAt": "2023-07-27T09:40:20Z",
#                         "diskUsage": 1678,
#                         "forkCount": 181,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Shell"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "InternLM"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 61
#                         },
#                         "issues": {
#                             "totalCount": 73
#                         },
#                         "watchers": {
#                             "totalCount": 28
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "igl",
#                         "description": "Intermediate Graphics Library (IGL) is a cross-platform library that commands the GPU. It provides a single low-level cross-platform interface on top of various graphics APIs (e.g. OpenGL, Metal and Vulkan).",
#                         "url": "https://github.com/facebook/igl",
#                         "stargazers": {
#                             "totalCount": 2240
#                         },
#                         "createdAt": "2023-07-07T15:57:14Z",
#                         "updatedAt": "2023-07-27T08:47:21Z",
#                         "diskUsage": 9466,
#                         "forkCount": 126,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "CMake"
#                                 },
#                                 {
#                                     "name": "C++"
#                                 },
#                                 {
#                                     "name": "Objective-C++"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Other"
#                         },
#                         "owner": {
#                             "login": "facebook"
#                         },
#                         "primaryLanguage": {
#                             "name": "C++"
#                         },
#                         "pullRequests": {
#                             "totalCount": 11
#                         },
#                         "issues": {
#                             "totalCount": 19
#                         },
#                         "watchers": {
#                             "totalCount": 48
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "llama-recipes",
#                         "description": "Examples and recipes for Llama 2 model",
#                         "url": "https://github.com/facebookresearch/llama-recipes",
#                         "stargazers": {
#                             "totalCount": 2043
#                         },
#                         "createdAt": "2023-07-17T07:33:48Z",
#                         "updatedAt": "2023-07-27T10:01:04Z",
#                         "diskUsage": 478,
#                         "forkCount": 210,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 },
#                                 {
#                                     "name": "Shell"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Other"
#                         },
#                         "owner": {
#                             "login": "facebookresearch"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 24
#                         },
#                         "issues": {
#                             "totalCount": 33
#                         },
#                         "watchers": {
#                             "totalCount": 26
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "docuseal",
#                         "description": "Open source DocuSign alternative. Create, fill, and sign digital documents \u270d\ufe0f",
#                         "url": "https://github.com/docusealco/docuseal",
#                         "stargazers": {
#                             "totalCount": 2030
#                         },
#                         "createdAt": "2023-07-03T19:54:54Z",
#                         "updatedAt": "2023-07-27T09:47:21Z",
#                         "diskUsage": 696,
#                         "forkCount": 51,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Dockerfile"
#                                 },
#                                 {
#                                     "name": "Ruby"
#                                 },
#                                 {
#                                     "name": "Procfile"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "GNU Affero General Public License v3.0"
#                         },
#                         "owner": {
#                             "login": "docusealco"
#                         },
#                         "primaryLanguage": {
#                             "name": "Ruby"
#                         },
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 16
#                         },
#                         "watchers": {
#                             "totalCount": 8
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Baichuan-13B",
#                         "description": "A 13B large language model developed by Baichuan Intelligent Technology",
#                         "url": "https://github.com/baichuan-inc/Baichuan-13B",
#                         "stargazers": {
#                             "totalCount": 1957
#                         },
#                         "createdAt": "2023-07-10T17:03:50Z",
#                         "updatedAt": "2023-07-27T09:19:10Z",
#                         "diskUsage": 16836,
#                         "forkCount": 125,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "baichuan-inc"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 3
#                         },
#                         "issues": {
#                             "totalCount": 103
#                         },
#                         "watchers": {
#                             "totalCount": 23
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Llama2-Chinese",
#                         "description": "Llama\u4e2d\u6587\u793e\u533a\uff0c\u6700\u597d\u7684\u4e2d\u6587Llama\u5927\u6a21\u578b\uff0c\u5b8c\u5168\u5f00\u6e90\u53ef\u5546\u7528",
#                         "url": "https://github.com/FlagAlpha/Llama2-Chinese",
#                         "stargazers": {
#                             "totalCount": 1900
#                         },
#                         "createdAt": "2023-07-19T04:45:23Z",
#                         "updatedAt": "2023-07-27T10:05:40Z",
#                         "diskUsage": 6877,
#                         "forkCount": 163,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Shell"
#                                 },
#                                 {
#                                     "name": "Dockerfile"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "FlagAlpha"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 10
#                         },
#                         "issues": {
#                             "totalCount": 25
#                         },
#                         "watchers": {
#                             "totalCount": 38
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "codeinterpreter-api",
#                         "description": "Open source implementation of the ChatGPT Code Interpreter \ud83d\udc7e",
#                         "url": "https://github.com/shroominic/codeinterpreter-api",
#                         "stargazers": {
#                             "totalCount": 1895
#                         },
#                         "createdAt": "2023-07-10T00:20:41Z",
#                         "updatedAt": "2023-07-27T09:59:28Z",
#                         "diskUsage": 383,
#                         "forkCount": 165,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "shroominic"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 13
#                         },
#                         "issues": {
#                             "totalCount": 41
#                         },
#                         "watchers": {
#                             "totalCount": 20
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Queryable",
#                         "description": "Run OpenAI's CLIP model on iOS to search photos.",
#                         "url": "https://github.com/mazzzystar/Queryable",
#                         "stargazers": {
#                             "totalCount": 1742
#                         },
#                         "createdAt": "2023-07-09T01:27:40Z",
#                         "updatedAt": "2023-07-27T09:55:44Z",
#                         "diskUsage": 899,
#                         "forkCount": 317,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Swift"
#                                 },
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "mazzzystar"
#                         },
#                         "primaryLanguage": {
#                             "name": "Swift"
#                         },
#                         "pullRequests": {
#                             "totalCount": 1
#                         },
#                         "issues": {
#                             "totalCount": 12
#                         },
#                         "watchers": {
#                             "totalCount": 12
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "BlackLotus",
#                         "description": "BlackLotus UEFI Windows Bootkit",
#                         "url": "https://github.com/ldpreload/BlackLotus",
#                         "stargazers": {
#                             "totalCount": 1544
#                         },
#                         "createdAt": "2023-07-12T17:14:40Z",
#                         "updatedAt": "2023-07-27T07:00:13Z",
#                         "diskUsage": 1346,
#                         "forkCount": 377,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "PHP"
#                                 },
#                                 {
#                                     "name": "C"
#                                 },
#                                 {
#                                     "name": "CSS"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "ldpreload"
#                         },
#                         "primaryLanguage": {
#                             "name": "C"
#                         },
#                         "pullRequests": {
#                             "totalCount": 2
#                         },
#                         "issues": {
#                             "totalCount": 12
#                         },
#                         "watchers": {
#                             "totalCount": 27
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Chess-Challenge",
#                         "description": "https://youtu.be/iScy18pVR58",
#                         "url": "https://github.com/SebLague/Chess-Challenge",
#                         "stargazers": {
#                             "totalCount": 1507
#                         },
#                         "createdAt": "2023-07-17T13:28:56Z",
#                         "updatedAt": "2023-07-27T10:05:08Z",
#                         "diskUsage": 3455,
#                         "forkCount": 842,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "GLSL"
#                                 },
#                                 {
#                                     "name": "C#"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "SebLague"
#                         },
#                         "primaryLanguage": {
#                             "name": "C#"
#                         },
#                         "pullRequests": {
#                             "totalCount": 55
#                         },
#                         "issues": {
#                             "totalCount": 261
#                         },
#                         "watchers": {
#                             "totalCount": 18
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "threads-api",
#                         "description": "Unofficial, Reverse-Engineered Node.js/TypeScript client for Meta's Threads. Supports Read and Write. Web UI Included.",
#                         "url": "https://github.com/junhoyeo/threads-api",
#                         "stargazers": {
#                             "totalCount": 1494
#                         },
#                         "createdAt": "2023-07-06T10:20:03Z",
#                         "updatedAt": "2023-07-27T09:37:27Z",
#                         "diskUsage": 16900,
#                         "forkCount": 114,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "TypeScript"
#                                 },
#                                 {
#                                     "name": "JavaScript"
#                                 },
#                                 {
#                                     "name": "CSS"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "junhoyeo"
#                         },
#                         "primaryLanguage": {
#                             "name": "TypeScript"
#                         },
#                         "pullRequests": {
#                             "totalCount": 129
#                         },
#                         "issues": {
#                             "totalCount": 125
#                         },
#                         "watchers": {
#                             "totalCount": 21
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "website",
#                         "description": "AGE animation official website URL release page\uff08AGE\u52a8\u6f2b\u5b98\u7f51\u7f51\u5740\u53d1\u5e03\u9875\uff09",
#                         "url": "https://github.com/agefanscom/website",
#                         "stargazers": {
#                             "totalCount": 1386
#                         },
#                         "createdAt": "2023-06-29T13:16:14Z",
#                         "updatedAt": "2023-07-27T09:49:20Z",
#                         "diskUsage": 4,
#                         "forkCount": 36,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": []
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "agefanscom"
#                         },
#                         "primaryLanguage": null,
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 1
#                         },
#                         "watchers": {
#                             "totalCount": 34
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "vaul",
#                         "description": "An unstyled drawer component for React.",
#                         "url": "https://github.com/emilkowalski/vaul",
#                         "stargazers": {
#                             "totalCount": 1366
#                         },
#                         "createdAt": "2023-07-16T11:24:46Z",
#                         "updatedAt": "2023-07-27T10:05:44Z",
#                         "diskUsage": 170,
#                         "forkCount": 22,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "JavaScript"
#                                 },
#                                 {
#                                     "name": "TypeScript"
#                                 },
#                                 {
#                                     "name": "CSS"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "emilkowalski"
#                         },
#                         "primaryLanguage": {
#                             "name": "TypeScript"
#                         },
#                         "pullRequests": {
#                             "totalCount": 5
#                         },
#                         "issues": {
#                             "totalCount": 3
#                         },
#                         "watchers": {
#                             "totalCount": 2
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "valibot",
#                         "description": "The modular and type safe schema library for validating structural data \ud83e\udd16",
#                         "url": "https://github.com/fabian-hiller/valibot",
#                         "stargazers": {
#                             "totalCount": 1179
#                         },
#                         "createdAt": "2023-07-07T10:31:24Z",
#                         "updatedAt": "2023-07-27T10:02:13Z",
#                         "diskUsage": 589,
#                         "forkCount": 9,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "JavaScript"
#                                 },
#                                 {
#                                     "name": "TypeScript"
#                                 },
#                                 {
#                                     "name": "MDX"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "fabian-hiller"
#                         },
#                         "primaryLanguage": {
#                             "name": "TypeScript"
#                         },
#                         "pullRequests": {
#                             "totalCount": 4
#                         },
#                         "issues": {
#                             "totalCount": 14
#                         },
#                         "watchers": {
#                             "totalCount": 8
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "charming",
#                         "description": "A visualization library for Rust",
#                         "url": "https://github.com/yuankunzhang/charming",
#                         "stargazers": {
#                             "totalCount": 1093
#                         },
#                         "createdAt": "2023-06-29T15:28:29Z",
#                         "updatedAt": "2023-07-27T08:45:09Z",
#                         "diskUsage": 1948,
#                         "forkCount": 20,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "JavaScript"
#                                 },
#                                 {
#                                     "name": "Rust"
#                                 },
#                                 {
#                                     "name": "Handlebars"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "yuankunzhang"
#                         },
#                         "primaryLanguage": {
#                             "name": "Rust"
#                         },
#                         "pullRequests": {
#                             "totalCount": 6
#                         },
#                         "issues": {
#                             "totalCount": 9
#                         },
#                         "watchers": {
#                             "totalCount": 4
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "unshackle",
#                         "description": "Open-source tool to bypass windows and linux passwords from bootable usb",
#                         "url": "https://github.com/Fadi002/unshackle",
#                         "stargazers": {
#                             "totalCount": 1044
#                         },
#                         "createdAt": "2023-07-19T22:30:28Z",
#                         "updatedAt": "2023-07-27T08:55:10Z",
#                         "diskUsage": 8020,
#                         "forkCount": 55,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Shell"
#                                 },
#                                 {
#                                     "name": "C++"
#                                 },
#                                 {
#                                     "name": "Python"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "GNU General Public License v3.0"
#                         },
#                         "owner": {
#                             "login": "Fadi002"
#                         },
#                         "primaryLanguage": {
#                             "name": "Shell"
#                         },
#                         "pullRequests": {
#                             "totalCount": 1
#                         },
#                         "issues": {
#                             "totalCount": 4
#                         },
#                         "watchers": {
#                             "totalCount": 13
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Chinese-Llama-2-7b",
#                         "description": "\u5f00\u6e90\u793e\u533a\u7b2c\u4e00\u4e2a\u80fd\u4e0b\u8f7d\u3001\u80fd\u8fd0\u884c\u7684\u4e2d\u6587 LLaMA2 \u6a21\u578b\uff01",
#                         "url": "https://github.com/LinkSoul-AI/Chinese-Llama-2-7b",
#                         "stargazers": {
#                             "totalCount": 949
#                         },
#                         "createdAt": "2023-07-20T08:30:42Z",
#                         "updatedAt": "2023-07-27T09:59:23Z",
#                         "diskUsage": 3819,
#                         "forkCount": 71,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Dockerfile"
#                                 },
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "LinkSoul-AI"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 17
#                         },
#                         "issues": {
#                             "totalCount": 16
#                         },
#                         "watchers": {
#                             "totalCount": 12
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "pr-agent",
#                         "description": "\ud83d\ude80CodiumAI PR-Agent: An AI-Powered \ud83e\udd16 Tool for Automated Pull Request Analysis, Feedback, Suggestions and More! \ud83d\udcbb\ud83d\udd0d",
#                         "url": "https://github.com/Codium-ai/pr-agent",
#                         "stargazers": {
#                             "totalCount": 922
#                         },
#                         "createdAt": "2023-07-05T21:02:15Z",
#                         "updatedAt": "2023-07-27T10:01:33Z",
#                         "diskUsage": 77705,
#                         "forkCount": 55,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Dockerfile"
#                                 },
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Shell"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "Codium-ai"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 121
#                         },
#                         "issues": {
#                             "totalCount": 24
#                         },
#                         "watchers": {
#                             "totalCount": 18
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Semantic-SAM",
#                         "description": "Official implementation of the paper \"Semantic-SAM: Segment and Recognize Anything at Any Granularity\"",
#                         "url": "https://github.com/UX-Decoder/Semantic-SAM",
#                         "stargazers": {
#                             "totalCount": 919
#                         },
#                         "createdAt": "2023-07-10T17:13:37Z",
#                         "updatedAt": "2023-07-27T09:48:58Z",
#                         "diskUsage": 36693,
#                         "forkCount": 40,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Shell"
#                                 },
#                                 {
#                                     "name": "C++"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "UX-Decoder"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 12
#                         },
#                         "issues": {
#                             "totalCount": 25
#                         },
#                         "watchers": {
#                             "totalCount": 20
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "llama2-chatbot",
#                         "description": "LLaMA v2 Chatbot",
#                         "url": "https://github.com/a16z-infra/llama2-chatbot",
#                         "stargazers": {
#                             "totalCount": 887
#                         },
#                         "createdAt": "2023-07-15T08:44:08Z",
#                         "updatedAt": "2023-07-27T09:10:30Z",
#                         "diskUsage": 95,
#                         "forkCount": 130,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Dockerfile"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "a16z-infra"
#                         },
#                         "primaryLanguage": {
#                             "name": "Python"
#                         },
#                         "pullRequests": {
#                             "totalCount": 18
#                         },
#                         "issues": {
#                             "totalCount": 8
#                         },
#                         "watchers": {
#                             "totalCount": 13
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "long_llama",
#                         "description": "LongLLaMA is a large language model capable of handling long contexts. It is based on OpenLLaMA and fine-tuned with the Focused Transformer (FoT) method.",
#                         "url": "https://github.com/CStanKonrad/long_llama",
#                         "stargazers": {
#                             "totalCount": 839
#                         },
#                         "createdAt": "2023-07-06T14:54:15Z",
#                         "updatedAt": "2023-07-27T06:20:01Z",
#                         "diskUsage": 948,
#                         "forkCount": 60,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Python"
#                                 },
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "CStanKonrad"
#                         },
#                         "primaryLanguage": {
#                             "name": "Jupyter Notebook"
#                         },
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 10
#                         },
#                         "watchers": {
#                             "totalCount": 19
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "Far-Cry-1-Source-Full",
# ...
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "JavaScript"
#                                 },
#                                 {
#                                     "name": "HTML"
#                                 },
#                                 {
#                                     "name": "Vue"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "CatsJuice"
#                         },
#                         "primaryLanguage": {
#                             "name": "TypeScript"
#                         },
#                         "pullRequests": {
#                             "totalCount": 19
#                         },
#                         "issues": {
#                             "totalCount": 13
#                         },
#                         "watchers": {
#                             "totalCount": 2
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "hackernews-personal-blogs",
#                         "description": "List of Public Blogs of Hacker News users",
#                         "url": "https://github.com/outcoldman/hackernews-personal-blogs",
#                         "stargazers": {
#                             "totalCount": 261
#                         },
#                         "createdAt": "2023-07-07T03:51:10Z",
#                         "updatedAt": "2023-07-25T21:21:28Z",
#                         "diskUsage": 220,
#                         "forkCount": 16,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Go"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "outcoldman"
#                         },
#                         "primaryLanguage": {
#                             "name": "Go"
#                         },
#                         "pullRequests": {
#                             "totalCount": 6
#                         },
#                         "issues": {
#                             "totalCount": 6
#                         },
#                         "watchers": {
#                             "totalCount": 4
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "clickvote",
#                         "description": "Add upvotes, likes, and reviews to any context \u2b50\ufe0f",
#                         "url": "https://github.com/clickvote/clickvote",
#                         "stargazers": {
#                             "totalCount": 260
#                         },
#                         "createdAt": "2023-07-08T17:24:22Z",
#                         "updatedAt": "2023-07-26T01:47:42Z",
#                         "diskUsage": 1072,
#                         "forkCount": 10,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "TypeScript"
#                                 },
#                                 {
#                                     "name": "JavaScript"
#                                 },
#                                 {
#                                     "name": "CSS"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "clickvote"
#                         },
#                         "primaryLanguage": {
#                             "name": "TypeScript"
#                         },
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 0
#                         },
#                         "watchers": {
#                             "totalCount": 5
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "openai-quickstart",
#                         "description": "A comprehensive guide to understanding and implementing large language models with hands-on examples using LangChain for AIGC applications.",
#                         "url": "https://github.com/DjangoPeng/openai-quickstart",
#                         "stargazers": {
#                             "totalCount": 256
#                         },
#                         "createdAt": "2023-07-17T15:43:10Z",
#                         "updatedAt": "2023-07-27T06:52:46Z",
#                         "diskUsage": 28960,
#                         "forkCount": 97,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "DjangoPeng"
#                         },
#                         "primaryLanguage": {
#                             "name": "Jupyter Notebook"
#                         },
#                         "pullRequests": {
#                             "totalCount": 23
#                         },
#                         "issues": {
#                             "totalCount": 2
#                         },
#                         "watchers": {
#                             "totalCount": 9
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "RedCloud-OS",
#                         "description": "RedCloudOS is a Cloud Adversary Simulation Operating System for Red Teams to assess the Cloud Security of Leading Cloud Service Providers (CSPs)",
#                         "url": "https://github.com/RedTeamOperations/RedCloud-OS",
#                         "stargazers": {
#                             "totalCount": 254
#                         },
#                         "createdAt": "2023-07-05T12:22:49Z",
#                         "updatedAt": "2023-07-24T21:40:33Z",
#                         "diskUsage": 4149,
#                         "forkCount": 26,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Shell"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "GNU General Public License v2.0"
#                         },
#                         "owner": {
#                             "login": "RedTeamOperations"
#                         },
#                         "primaryLanguage": {
#                             "name": "Shell"
#                         },
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 2
#                         },
#                         "watchers": {
#                             "totalCount": 6
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "LLM-Reading-List",
#                         "description": "LLM papers I'm reading, mostly on inference and model compression",
#                         "url": "https://github.com/evanmiller/LLM-Reading-List",
#                         "stargazers": {
#                             "totalCount": 254
#                         },
#                         "createdAt": "2023-07-26T15:16:28Z",
#                         "updatedAt": "2023-07-27T10:05:57Z",
#                         "diskUsage": 2,
#                         "forkCount": 9,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": []
#                         },
#                         "licenseInfo": null,
#                         "owner": {
#                             "login": "evanmiller"
#                         },
#                         "primaryLanguage": null,
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 0
#                         },
#                         "watchers": {
#                             "totalCount": 9
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "prompts-royale",
#                         "description": "Automatically create prompts and make them fight each other to know which is the best",
#                         "url": "https://github.com/meistrari/prompts-royale",
#                         "stargazers": {
#                             "totalCount": 253
#                         },
#                         "createdAt": "2023-07-12T03:27:22Z",
#                         "updatedAt": "2023-07-27T00:04:24Z",
#                         "diskUsage": 498,
#                         "forkCount": 18,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "TypeScript"
#                                 },
#                                 {
#                                     "name": "Vue"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Other"
#                         },
#                         "owner": {
#                             "login": "meistrari"
#                         },
#                         "primaryLanguage": {
#                             "name": "Vue"
#                         },
#                         "pullRequests": {
#                             "totalCount": 3
#                         },
#                         "issues": {
#                             "totalCount": 8
#                         },
#                         "watchers": {
#                             "totalCount": 5
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "LLMDrift",
#                         "description": null,
#                         "url": "https://github.com/lchen001/LLMDrift",
#                         "stargazers": {
#                             "totalCount": 253
#                         },
#                         "createdAt": "2023-07-18T05:54:14Z",
#                         "updatedAt": "2023-07-27T09:01:32Z",
#                         "diskUsage": 3850,
#                         "forkCount": 20,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "Jupyter Notebook"
#                                 },
#                                 {
#                                     "name": "Python"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "Apache License 2.0"
#                         },
#                         "owner": {
#                             "login": "lchen001"
#                         },
#                         "primaryLanguage": {
#                             "name": "Jupyter Notebook"
#                         },
#                         "pullRequests": {
#                             "totalCount": 0
#                         },
#                         "issues": {
#                             "totalCount": 5
#                         },
#                         "watchers": {
#                             "totalCount": 9
#                         }
#                     }
#                 },
#                 {
#                     "node": {
#                         "name": "flipper-zero-evil-portal",
#                         "description": "Evil portal app for the flipper zero + WiFi dev board",
#                         "url": "https://github.com/bigbrodude6119/flipper-zero-evil-portal",
#                         "stargazers": {
#                             "totalCount": 245
#                         },
#                         "createdAt": "2023-06-30T21:10:23Z",
#                         "updatedAt": "2023-07-27T07:58:18Z",
#                         "diskUsage": 1086,
#                         "forkCount": 37,
#                         "isArchived": false,
#                         "isFork": false,
#                         "isMirror": false,
#                         "isPrivate": false,
#                         "languages": {
#                             "nodes": [
#                                 {
#                                     "name": "C++"
#                                 },
#                                 {
#                                     "name": "C"
#                                 },
#                                 {
#                                     "name": "HTML"
#                                 }
#                             ]
#                         },
#                         "licenseInfo": {
#                             "name": "MIT License"
#                         },
#                         "owner": {
#                             "login": "bigbrodude6119"
#                         },
#                         "primaryLanguage": {
#                             "name": "HTML"
#                         },
#                         "pullRequests": {
#                             "totalCount": 30
#                         },
#                         "issues": {
#                             "totalCount": 19
#                         },
#                         "watchers": {
#                             "totalCount": 16
#                         }
#                     }
#                 }
#             ]
#         }
#     }
# }

# %%
# Get the list of repository nodes
repos_list = data['data']['repos']['edges']
# Flatten the data into a pandas DataFrame
# json_normalize is deprecated since pandas v1.3.0, hence use pandas.json_normalize
# Let's extract the 'node' key in each dictionary and create a new list
node_list = [repo['node'] for repo in repos_list]

# Normalize
df = pd.json_normalize(node_list, 
      meta=['name', 'description', 'url', 
      ['stargazers', 'totalCount'],
      'createdAt', 'updatedAt',
      'diskUsage', 'forkCount',
      'isArchived', 'isFork',
      'isMirror', 'isPrivate',
      ['licenseInfo', 'name'],
      ['owner', 'login'],
      ['primaryLanguage', 'name'],
      ['pullRequests', 'totalCount'],
      ['issues', 'totalCount'],
      ['watchers', 'totalCount']], errors='ignore')

# Convert numeric columns
numeric_cols = ['stargazers.totalCount', 'diskUsage', 'forkCount', 
                'pullRequests.totalCount', 'issues.totalCount', 'watchers.totalCount']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Print the DataFrame
print(df[['name', 'primaryLanguage.name', 'stargazers.totalCount', 'createdAt', 'description']])
# Out:
#                         name primaryLanguage.name  stargazers.totalCount  \
# 0                   llama2.c               Python                   8452
# 1             python-mastery               Python                   6868
# 2                    MetaGPT               Python                   6437
# 3        gpt-prompt-engineer     Jupyter Notebook                   4128
# 4                   InternLM               Python                   2278
# ..                       ...                  ...                    ...
# 95               RedCloud-OS                Shell                    254
# 96          LLM-Reading-List                  NaN                    254
# 97            prompts-royale                  Vue                    253
# 98                  LLMDrift     Jupyter Notebook                    253
# 99  flipper-zero-evil-portal                 HTML                    245
#
#                createdAt                                        description
# 0   2023-07-23T05:15:06Z            Inference Llama 2 in one file of pure C
# 1   2023-07-17T01:11:15Z        Advanced Python Mastery (course by @dabeaz)
# 2   2023-06-30T09:04:55Z  🌟 The Multi-Agent Framework: Given one line Re...
# 3   2023-07-04T03:47:09Z                                               None
# 4   2023-07-06T04:52:06Z  InternLM has open-sourced a 7 billion paramete...
# ..                   ...                                                ...
# 95  2023-07-05T12:22:49Z  RedCloudOS is a Cloud Adversary Simulation Ope...
# 96  2023-07-26T15:16:28Z  LLM papers I'm reading, mostly on inference an...
# 97  2023-07-12T03:27:22Z  Automatically create prompts and make them fig...
# 98  2023-07-18T05:54:14Z                                               None
# 99  2023-06-30T21:10:23Z  Evil portal app for the flipper zero + WiFi de...
#
# [100 rows x 5 columns]

# %%
df.to_csv('repo_data.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Construct the arXiv API request URL
base_url = "http://export.arxiv.org/api/query?"
search_query = "all:electron"  # replace with your query
start = 0  # start at the beginning
total_results = 2000  # maximum results is 2000
url = f"{base_url}search_query={search_query}&sortBy=submittedDate&sortOrder=descending&max_results={total_results}"

response = requests.get(url)

# Parse response using BeautifulSoup
soup = BeautifulSoup(response.content, 'xml')

# Extract relevant information for each entry (modify this as needed)
entries = []
for entry in soup.findAll('entry'):
    title = entry.title.text
    summary = entry.summary.text
    url = entry.id.text
    published = entry.published.text
    authors = [author.find('name').text for author in entry.findAll('author')]
    entries.append({'title': title, 'summary': summary, 'url': url, 'published': published, 'authors': authors})

# Convert list of entries to pandas DataFrame
papers_df = pd.DataFrame(entries)
papers_df.head()
# Out:
#                                                title  \
# 0        Generation and Life Cycle of Solar Spicules
# 1  A new Low Gain Avalanche Diode concept: the do...
# 2  Non-chiral one-dimensional sates propagating i...
# 3  High-speed plasma measurements with a plasma i...
# 4  Floquet engineering of the Lifshitz phase tran...
#
#                                              summary  \
# 0    Physical mechanism for the creation of solar...
# 1    This paper describes the new concept of the ...
# 2    Boundaries between structural twins of bilay...
# 3    Plasma impedance probes (PIPs) are a type of...
# 4    Within the Floquet theory of periodically dr...
#
#                                  url             published  \
# 0  http://arxiv.org/abs/2307.14328v1  2023-07-26T17:46:56Z
# 1  http://arxiv.org/abs/2307.14320v1  2023-07-26T17:37:24Z
# 2  http://arxiv.org/abs/2307.14293v1  2023-07-26T16:49:44Z
# 3  http://arxiv.org/abs/2307.14263v1  2023-07-26T15:50:47Z
# 4  http://arxiv.org/abs/2307.14258v1  2023-07-26T15:42:26Z
#
#                                              authors
# 0                     [Hamid Saleem, Zain H. Saleem]
# 1  [F. Carnesecchi, S. Strazzi, A. Alici, R. Arci...
# 2  [V. V. Enaldiev, C. Moulsdale, A. K. Geim, V. ...
# 3  [John W. Brooks, Erik M. Tejero, Matthew C. Pa...
# 4  [I. V. Iorsh, D. D. Sedov, S. A. Kolodny, R. E...

# %%
papers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      2000 non-null   object
#  1   summary    2000 non-null   object
#  2   url        2000 non-null   object
#  3   published  2000 non-null   object
#  4   authors    2000 non-null   object
# dtypes: object(5)
# memory usage: 78.2+ KB

# %%
papers_df.tail(5)
# Out:
#                                                   title  \
# 1995  On the capillary discharge in the high repetit...
# 1996  Implementation of the SCAN Exchange-Correlatio...
# 1997  The Ferris ferromagnetic resonance technique: ...
# 1998  Novel slow dynamics of phase transition in the...
# 1999  Equivalence between State-Space Stability Anal...
#
#                                                 summary  \
# 1995    We investigate the main physical processes t...
# 1996    Kohn-Sham density functional theory (DFT) is...
# 1997    Measurements of ferromagnetic resonance (FMR...
# 1998    DyRu2Si2 is a frustrated magnet to exhibit m...
# 1999    Stability of power electronic converters con...
#
#                                     url             published  \
# 1995  http://arxiv.org/abs/2305.19679v1  2023-05-31T09:20:31Z
# 1996  http://arxiv.org/abs/2305.19662v1  2023-05-31T08:58:10Z
# 1997  http://arxiv.org/abs/2306.01783v1  2023-05-31T08:48:29Z
# 1998  http://arxiv.org/abs/2305.19656v1  2023-05-31T08:41:03Z
# 1999  http://arxiv.org/abs/2305.19655v1  2023-05-31T08:40:47Z
#
#                                                 authors
# 1995  [P. Sasorov, G. Bagdasarov, N. Bobrova, G. Gri...
# 1996  [Renxi Liu, Daye Zheng, Xinyuan Liang, Xinguo ...
# 1997  [Amit Rothschild, Benjamin Assouline, Nadav Am...
# 1998  [Subaru Yoshimoto, Yoshikazu Tabata, Takeshi W...
# 1999  [Pablo Rodriguez-Ortega, Javier Roldan-Perez, ...

# %%
papers_df.head(5)
# Out:
#                                                title  \
# 0        Generation and Life Cycle of Solar Spicules
# 1  A new Low Gain Avalanche Diode concept: the do...
# 2  Non-chiral one-dimensional sates propagating i...
# 3  High-speed plasma measurements with a plasma i...
# 4  Floquet engineering of the Lifshitz phase tran...
#
#                                              summary  \
# 0    Physical mechanism for the creation of solar...
# 1    This paper describes the new concept of the ...
# 2    Boundaries between structural twins of bilay...
# 3    Plasma impedance probes (PIPs) are a type of...
# 4    Within the Floquet theory of periodically dr...
#
#                                  url             published  \
# 0  http://arxiv.org/abs/2307.14328v1  2023-07-26T17:46:56Z
# 1  http://arxiv.org/abs/2307.14320v1  2023-07-26T17:37:24Z
# 2  http://arxiv.org/abs/2307.14293v1  2023-07-26T16:49:44Z
# 3  http://arxiv.org/abs/2307.14263v1  2023-07-26T15:50:47Z
# 4  http://arxiv.org/abs/2307.14258v1  2023-07-26T15:42:26Z
#
#                                              authors
# 0                     [Hamid Saleem, Zain H. Saleem]
# 1  [F. Carnesecchi, S. Strazzi, A. Alici, R. Arci...
# 2  [V. V. Enaldiev, C. Moulsdale, A. K. Geim, V. ...
# 3  [John W. Brooks, Erik M. Tejero, Matthew C. Pa...
# 4  [I. V. Iorsh, D. D. Sedov, S. A. Kolodny, R. E...

# %%
papers_df.to_csv("papers_data.csv", index=False)
